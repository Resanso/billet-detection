# %%
# !pip install ultralytics roboflow
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 3.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 94 kB 3.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 802 kB 15.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 11.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 66 kB 7.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 54.8 MB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 39.3 MB 4.1 MB/s eta 0:00:011
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="oHx7pU0sa63ZshNQw4C3")
project = rf.workspace("resans-workspace").project("billet-detection-v26oo")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Billet-Detection-2 in yolov11:: 100%|██████████| 306/306 [00:00<00:00, 3878.09it/s]

# %%
from ultralytics import YOLO

# Mengunduh otak dasar YOLOv11 (sangat ringan)
model = YOLO('yolo11n.pt') 

# PROSES TRAINING DIMULAI!
# Pastikan nama folder 'dataset.location' sesuai dengan yang terunduh dari Cell 2
# device='mps' akan menyuruh Mac Anda menggunakan akselerasi GPU Apple secara maksimal!
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,             # AI akan belajar membaca foto sebanyak 50 putaran
    imgsz=640,             # Resolusi gambar saat belajar
    device='mps',          # Akselerasi Hardware Mac
    batch=16               # Jumlah foto yang diproses sekaligus
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/mac/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.17 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# ...
